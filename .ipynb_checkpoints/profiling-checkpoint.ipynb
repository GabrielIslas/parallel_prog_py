# %%
import pi_approx
import pi_approx_mp
import time

# %%
test_N = [10, 100, 1000, 10000, 100000, 1000000, 10000000, 100000000]

# %%
normal_times = []
for N in test_N:
    start = time.time_ns()
    pi_approx.approximate_pi(N)
    end = time.time_ns()
    normal_times.append(end - start)

# %%
normal_times
# Out:
# [21109, 16991, 163145, 1684135, 21818855, 168866610, 1680911827, 16842521505]

# %%
mp_times = []
for N in test_N:
    start = time.time_ns()
    pi_approx_mp.main(N)
    end = time.time_ns()
    mp_times.append(end - start)
# Out:
# 2.8901623685066915
# 3.1258902412654117
# 3.1435554669110273
# 3.1417914776113225
# 3.141612616401986
# 3.1415946524138105
# 3.1415928535526056
# 3.1415926735886166

# %%
mp_times
# Out:
# [51400041,
#  38804450,
#  35161916,
#  33470541,
#  34676692,
#  41260158,
#  130870998,
#  1650820683]

# %%
# 10
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 2.8901623685066915
#
# real	0m2.171s
# user	0m1.015s
# sys	0m0.744s

# %% [markdown]
# 100

# %%
# 100
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.1604170317790454
#
# real	0m2.141s
# user	0m0.933s
# sys	0m0.736s

# %%
# 1000
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.1435554669110273
#
# real	0m2.146s
# user	0m0.946s
# sys	0m0.703s

# %%
# 10000
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.1417914776113225
#
# real	0m2.154s
# user	0m0.920s
# sys	0m0.752s

# %%
# 100000
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.1416126164019857
#
# real	0m2.125s
# user	0m0.953s
# sys	0m0.732s

# %%
# 1000000
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.141594652413811
#
# real	0m2.157s
# user	0m0.861s
# sys	0m0.790s

# %%
# 10000000
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.1415928535526048
#
# real	0m2.222s
# user	0m1.157s
# sys	0m0.838s

# %%
# 100000000
# !time mpiexec -n 4 python pi_approx_mpi.py
# Out:
# pi = 3.1415926735886153
#
# real	0m4.583s
# user	0m3.782s
# sys	0m3.153s

# %%
mpi_times_seconds = [2.171, 2.141, 2.146, 2.154, 2.125, 2.157, 2.222, 4.583]

# %%
# Converting to nanoseconds like everything else
mpi_times = [mpi_time * 1000000000 for mpi_time in mpi_times_seconds]

# %%
mpi_times
# Out:
# [2171000000.0,
#  2141000000.0,
#  2146000000.0,
#  2154000000.0,
#  2125000000.0,
#  2157000000.0,
#  2222000000.0,
#  4583000000.0]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_N, normal_times, label='normal')  
plt.plot(test_N, mp_times, label='multiprocessing')  
plt.plot(test_N, mpi_times, label='mpi4py')
plt.title('Runtime comparison')  
plt.xlabel('N')                
plt.ylabel('Time (ns)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_N, normal_times, label='normal')  
plt.plot(test_N, mp_times, label='multiprocessing')  
plt.plot(test_N, mpi_times, label='mpi4py')
plt.xscale("log")
plt.title('Runtime comparison')  
plt.xlabel('N')                
plt.ylabel('Time (ns)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_N, normal_times, label='normal')  
plt.plot(test_N, mp_times, label='multiprocessing')  
plt.plot(test_N, mpi_times, label='mpi4py')
plt.xscale("log")
plt.yscale("log")
plt.title('Runtime comparison')  
plt.xlabel('N')                
plt.ylabel('Time (ns)')
plt.legend()
plt.show()
